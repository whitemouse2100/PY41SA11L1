# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Vẽ thông qua matplot
plt.plot(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Title")
plt.show()

# %%
#một hình hình mà có 1 dòng và 2 cột, và trong đó cái hinh plt.subplot(1,2,1) sẽ nằm ở vị trí thứ nhất 1
plt.subplot(1,2,1)
plt.plot(x,y,'r')
#một hình hình mà có 1 dòng và 2 cột, và trong đó cái hinh plt.subplot(1,2,2) sẽ nằm ở vị trí thứ nhất 2
plt.subplot(1,2,2)
plt.plot(x,y,'g')

# %%
plt.subplots(3,2)
# Out:
# (<Figure size 432x288 with 6 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
fig=plt.figure() #cấu hình mới tạo ra một một đối tượng mới hoàn toàn
#left,bottom,width,height
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel("X Label")
axes.set_ylabel("Y label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.15,0.5,0.5])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title("Larger plot")
axes2.plot(y,x)
axes2.set_title("Smaler plot")
# Out:
# Text(0.5, 1.0, 'Smaler plot')

# %%
fig=plt.figure()
fig,axes=plt.subplots(1,2)
for plot in axes:
    plot.plot(x,y)

# %%
fig=plt.figure()
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y)
axes[0].set_title("First Plot")
axes[1].plot(y,x)
axes[1].set_title("Second Plot")
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
#Figure Size và DPI

# %%
fig=plt.figure(figsize=(3,2))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)

# %%
fig.savefig("mypicture.png")

# %%
fig=plt.figure(figsize=(8,2))
fig,axe=plt.subplots(2,1)
axe[0].plot(x,y)
axe[1].plot(x,y)

# %%
fig.savefig("mypicture1.png")

# %%
fig.savefig("mypicture1.jpg",dpi=200)

# %%
fig=plt.figure()
ax=fig.add_axes((0,0,1,1))
ax.plot(x,y,label="Đường 1")
ax.plot(y,x,label="Đường 2")
#ax.legend()
ax.legend(loc=5)#https://matplotlib.org/stable/api/legend_api.html?highlight=legend#module-matplotlib.legend
